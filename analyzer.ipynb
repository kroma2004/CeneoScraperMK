# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
print(*[file.split(".")[0] for file in os.listdir("opinions")], sep="\n")
# Out:
# 70524600

# %%
product_id = input("Podaj kod produktu: ")
opinions = pd.read_json(f'opinions/{product_id}.json')
opinions.stars = opinions.stars.apply(lambda s: s.split("/")[0].replace(",",".")).astype(float)
opinions
# Out:
#    opinion_id            author    recommend  stars  \
# 0    10455842             Aneta      Polecam    5.0
# 1    10387038          rarityyy      Polecam    5.0
# 2    16189483             s...9      Polecam    5.0
# 3    17860455             m...a      Polecam    4.0
# 4     8777524            Alojzy      Polecam    5.0
# 5    14103335             a...j         None    3.5
# 6    14942189             b...k      Polecam    5.0
# 7    14864399             i...5      Polecam    4.5
# 8    16131641             d...9      Polecam    4.5
# 9     8999193  Użytkownik Ceneo  Nie polecam    0.5
#
#                                              content                  cons  \
# 0  Jestem bardzo zadowolona z parownicy. Ma duży ...                    []
# 1  Jestem bardzo zadowolona z zakupu. Parownica s...                    []
# 2  sprawdzałem wiodącego producenta , i po dniu u...                    []
# 3  Jeszcze jestem na etapie testowania, poznawani...                    []
# 4  parownicą jestem bardzo zachwycony jest super ...                    []
# 5  Ogólnie jestem zadowolona, bardzo przydatne ur...                    []
# 6  na razie uczę się używać ale jak na początek t...                    []
# 7  Jednak chyba moc powinna być  nieco większa,  ...                    []
# 8  Jest  ok , wreszcie mam wyprasowane  rzeczy  k...                    []
# 9  Parownica zupełnie nie sprawdziła się w codzie...  [łatwość prasowania]
#
#                                                 pros         opinion_date  \
# 0  [dużo pary, ładnie rizprasowuje zagniecenia, ł...  2019-04-28 16:24:34
# 1                  [łatwość prasowania, skuteczność]  2019-04-12 10:04:57
# 2  [głośność pracy, skuteczność, szybko się nagrz...  2022-06-09 09:59:18
# 3              [głośność pracy, szybko się nagrzewa]  2023-09-01 09:26:44
# 4           [głośność pracy, skuteczność, wydajność]  2018-12-20 08:52:37
# 5  [głośność pracy, skuteczność, szybko się nagrz...  2021-03-12 09:46:50
# 6  [dużo pary, głośność pracy, ładnie rizprasowuj...  2021-09-10 08:14:18
# 7           [głośność pracy, skuteczność, wydajność]  2021-08-20 07:48:15
# 8                                                 []  2022-05-26 09:00:57
# 9                                           [ciężar]  2019-01-28 13:54:45
#
#          purchase_date  up_vote  down_vote
# 0  2019-03-26 11:37:21        3          0
# 1  2019-03-08 19:58:53        2          2
# 2  2022-05-31 20:08:51        1          0
# 3  2023-08-18 10:26:53        1          0
# 4  2018-12-15 15:43:21        1          0
# 5  2021-02-04 22:41:06        1          2
# 6  2021-08-30 21:41:17        1          0
# 7  2021-08-05 22:20:21        1          0
# 8  2022-05-21 13:40:09        1          0
# 9                 None       10          5

# %%
opinions_count = opinions.shape[0]
pros_count = opinions.pros.astype(bool).sum()
cons_count = opinions.cons.astype(bool).sum()
average_stars = opinions.stars.mean()
average_stars
# Out:
# 4.2

# %%
stars_distribution = opinions.stars.value_counts().reindex(np.arange(0,5.5,0.5))
ax = stars_distribution.plot.bar(color = "lightskyblue")
ax.set_title(f"Histogram częstości ocen w opiniach o produkcie {product_id}")
ax.set_xlabel("Liczba gwiazdek")
ax.set_ylabel("Liczba opinii")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
ax.bar_label(ax.containers[0],  label_type='edge', fmt=lambda l: int(l) if l > 0 else '')
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, '1'),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5')]

# %%
stars_distribution = opinions.stars.value_counts().reindex(np.arange(0,5.5,0.5))
ax = stars_distribution.plot.bar(color = "lightskyblue")
ax.set_title(f"Histogram częstości ocen w opiniach o produkcie {product_id}")
ax.set_xlabel("Liczba gwiazdek")
ax.set_ylabel("Liczba opinii")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
ax.bar_label(ax.containers[0],  label_type='edge', fmt=lambda l: int(l) if l > 0 else '')
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, '1'),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5')]

# %%
stars_distribution = opinions.stars.value_counts().reindex(np.arange(0,5.5,0.5))
ax = stars_distribution.plot.bar(color = "lightskyblue")
ax.set_title(f"Histogram częstości ocen w opiniach o produkcie {product_id}")
ax.set_xlabel("Liczba gwiazdek")
ax.set_ylabel("Liczba opinii")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
ax.bar_label(ax.containers[0],  label_type='edge', fmt=lambda l: int(l) if l > 0 else '')
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, '1'),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5')]

# %%
recommendations_distribution = opinions.recommend.value_counts(dropna=False).reindex(["Polecam", "Nie polecam", None])
recommendations_distribution.plot.pie(
    autopct = lambda p: f'{round(p):.1f}%' if p > 0 else '',
    label = "",
    colors = ['forestgreen', 'crimson', 'gray'],
    labels = ['Polecam', 'Nie polecam', 'Nie mam zdania']
    )
plt.title(f"Udział  rekomendacji w opiniach o produkcie {product_id}")
# Out:
# Text(0.5, 1.0, 'Udział  rekomendacji w opiniach o produkcie 70524600')
